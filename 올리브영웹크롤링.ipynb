# %% [markdown]
# ---
# # selunium

# %%
# 검색어 창을 찾아 search 변수에 저장 (By.CLASS_NAME 방식)
#search_box = driver.find_element(By.CLASS_NAME, 'gLFyf')
# 검색어 창을 찾아 search 변수에 저장 (By.XPATH 방식)
search_box = driver.find_element(By.XPATH, '//*[@id="APjFqb"]')

# %%
search_box.send_keys('파이썬')
search_box.send_keys(Keys.RETURN)
time.sleep(1)

# %%
# selenium의 webdriver를 사용하기 위한 import
from selenium import webdriver

# selenium으로 키를 조작하기 위한 import
from selenium.webdriver.common.keys import Keys

# 페이지 로딩을 기다리는데에 사용할 time 모듈 import
import time

# %%
driver = webdriver.Chrome()

# %%
url = "https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=1000001000700080011&fltDispCatNo=&prdSort=01&pageIdx=1&rowsPerPage=24&searchTypeSort=btn_thumb&plusButtonFlag=N&isLoginCnt=1&aShowCnt=0&bShowCnt=0&cShowCnt=0&trackingCd=Cat1000001000700080011_Small&amplitudePageGubun=&t_page=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EA%B4%80&t_click=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EC%83%81%EC%84%B8_%EC%86%8C%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC&midCategory=%EB%A9%94%EC%9D%B4%ED%81%AC%EC%97%85&smallCategory=%EC%A0%84%EC%B2%B4&checkBrnds=&lastChkBrnd=&t_1st_category_type=%EB%8C%80_%EB%A7%A8%EC%A6%88%EC%BC%80%EC%96%B4&t_2nd_category_type=%EC%A4%91_%EB%A9%94%EC%9D%B4%ED%81%AC%EC%97%85&t_3rd_category_type=%EC%86%8C_%EC%A0%84%EC%B2%B4"


driver.get(url)

time.sleep(3)

# %% [markdown]
# # 크롬불러오기

# %%
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
#  selenium의 webdriver를 사용하기 위한 import
from selenium import webdriver
# selenium으로 무엇인가 입력하기 위한 import
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
# 페이지 로딩을 기다리는데에 사용할 time 모듈 import
import time
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
from selenium.webdriver.chrome.options import Options

# %%
options = Options()

options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/120.0.0.0 Safari/537.36"
)

# 크롬드라이버 실행
# service= Service(ChromeDriverManager().install()),
driver = webdriver.Chrome(options=options)

# %%
url = "https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=1000001000700080011&fltDispCatNo=&prdSort=01&pageIdx=1&rowsPerPage=24&searchTypeSort=btn_thumb&plusButtonFlag=N&isLoginCnt=1&aShowCnt=0&bShowCnt=0&cShowCnt=0&trackingCd=Cat1000001000700080011_Small&amplitudePageGubun=&t_page=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EA%B4%80&t_click=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EC%83%81%EC%84%B8_%EC%86%8C%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC&midCategory=%EB%A9%94%EC%9D%B4%ED%81%AC%EC%97%85&smallCategory=%EC%A0%84%EC%B2%B4&checkBrnds=&lastChkBrnd=&t_1st_category_type=%EB%8C%80_%EB%A7%A8%EC%A6%88%EC%BC%80%EC%96%B4&t_2nd_category_type=%EC%A4%91_%EB%A9%94%EC%9D%B4%ED%81%AC%EC%97%85&t_3rd_category_type=%EC%86%8C_%EC%A0%84%EC%B2%B4"


#크롬 드라이버에 url 주소 넣고 실행
driver.get(url)

# 페이지가 완전히 로딩되도록 3초동안 기다림
time.sleep(3)

# %% [markdown]
# "https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=1000001000700080011&fltDispCatNo=&prdSort=01&pageIdx=1&rowsPerPage=24&searchTypeSort=btn_thumb&plusButtonFlag=N&isLoginCnt=1&aShowCnt=0&bShowCnt=0&cShowCnt=0&trackingCd=Cat1000001000700080011_Small&amplitudePageGubun=CHK_BRAND&t_page=&t_click=&midCategory=%EC%BF%A0%EC%85%98%2F%ED%8C%8C%EC%9A%B4%EB%8D%B0%EC%9D%B4%EC%85%98&smallCategory=%EC%A0%84%EC%B2%B4&checkBrnds=%EA%B7%B8%EB%9D%BC%ED%8E%9C%2C%EB%8B%A4%EC%8A%88%2C%EB%91%90%EC%9E%89%EC%99%93%2C%EB%B9%84%EB%A0%88%EB%94%94%2C%EC%98%A4%EB%B8%8C%EC%A0%9C&lastChkBrnd=%EC%98%A4%EB%B8%8C%EC%A0%9C&searchOnlBrndCdArr=A001624&searchOnlBrndCdArr=A001316&searchOnlBrndCdArr=A011852&searchOnlBrndCdArr=A003025&searchOnlBrndCdArr=A003713"

# %%
li = driver.find_element(By.XPATH,'//*[@id="Contents"]/ul[2]/li[1]')
li
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="edaae6860a64a285734933c7716dd7ed", element="f.7C3B69358B0C978838F6F1D7754A3081.d.C12D77C0428D4EE9DE6A228AF5C88896.e.1985")>

# %%
li2 = driver.find_elements(By.CSS_SELECTOR,'div.prd_info')
li2
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[5], line 1
#
# ----> 1 li2 = driver.find_elements(By.CSS_SELECTOR,'div.prd_info')
#
#       2 li2
#
#
#
# NameError: name 'By' is not defined

# %%
len(li2)

# %%
items = []
for li in li2:
    items.append(li.text)

# %%
items

# %% [markdown]
# # 기본정보

# %%
brand_selector = "div.prd_info > div.prd_name > a > span.tx_brand"
name_selector = "div.prd_info > div.prd_name > a > p.tx_name"
price_selector = "div.prd_info > p.prd_price > span.tx_cur> span.tx_num"
url_selector = "div.prd_info > div.prd_name > a"

# %%
brand = driver.find_elements(By.CSS_SELECTOR, brand_selector)
cosmetic = driver.find_elements(By.CSS_SELECTOR, name_selector)
price = driver.find_elements(By.CSS_SELECTOR, price_selector)
url = driver.find_elements(By.CSS_SELECTOR, url_selector)

# %%
brand.text
# Out:
# '오브제'

# %%
brand.text
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[23], line 1
#
# ----> 1 brand.text
#
#
#
# AttributeError: 'list' object has no attribute 'text'

# %%
[b.text for b in brand]
# Out:
# ['오브제',
#  '비레디',
#  '오브제',
#  '비레디',
#  '정샘물',
#  '그라펜',
#  '그라펜',
#  '라끌랑',
#  '듀이셀',
#  '라끌랑',
#  '두잉왓',
#  '다슈',
#  '다슈',
#  '그라펜',
#  '다슈',
#  '다슈',
#  '오브제',
#  '라끌랑',
#  '원오브뎀',
#  '엠도씨',
#  '듀이셀',
#  '스웨거',
#  '듀이셀',
#  '비레디']

# %%
url_list = [link.get_attribute('href') for link in link_element]

# %%
for i in price:
    print(i.text)
# Out:
# 30,100
# 32,900
# 23,100
# 34,900
# 29,700
# 33,300
# 33,100
# 24,900
# 24,800
# 22,900
# 27,200
# 26,500
# 33,900
# 35,100
# 35,000
# 17,800
# 24,000
# 9,900
# 27,000
# 29,000
# 33,900
# 36,000
# 29,000
# 24,900

# %%
results = []
for (i,v, c, u ) in zip(brand, cosmetic, price, url):
    b_text = i.text 
    c_text = v.text
    p_text = c.text
    u_text = u.get_attribute("href")
    results.append({'브랜드': b_text, '이름' : c_text, '가격' : p_text.replace(",",""), 'url': u_text})

df = pd.DataFrame(results)
df
# Out:
#      브랜드                                                이름     가격  \
# 0    오브제                 오브제 내추럴 커버 파운데이션 기획세트(+클렌징폼 50ml)  36800
# 1    비레디                                 비레디 블루 파운데이션 35ml  29000
# 2    오브제          [덱스 PICK]오브제 퍼펙트 옴므 쿠션 15g (SPF50+PA+++)  34900
# 3    비레디                    비레디 블루 쿠션 4세대 15g(SPF 34 PA++)  26900
# 4    정샘물   [밀착쿠션/OY단독기획/전용퍼프2P 증정] 정샘물 맨 슬림핏 누더 쿠션 (기획/단품)  27200
# 5    그라펜               [맨즈파데1등] 그라펜 팁 스케치 멀티 커버 파운데이션 20ml  32000
# 6    그라펜                          [착붙쿠션] 그라펜 핸섬 커버쿠션 2종 택1  19000
# 7    라끌랑                               라끌랑 슈퍼쉴드 옴므쿠션 2종 택1  39000
# 8    듀이셀                                 듀이셀 트루빔 파운데이션 12g  33000
# 9    라끌랑                             라끌랑 내츄럴 커버 옴므쿠션 3종 택1  31500
# 10   두잉왓                       두잉왓 소프트 블러링 필터 쿠션 15g 단품/기획  27900
# 11    다슈  다슈 맨즈 멀티 커버 스틱 파운데이션 12g 뉴트럴베이지 기획(+미니 톤 컨트롤 로션)  24800
# 12    다슈                            다슈 맨즈 아쿠아 매트 비비 쿠션 15g  17800
# ...

# %%
cos_info = df.copy()

# %%
cos_info['링크'] = url_list

# %%
cos_info['종류'] = ['스틱파운데이션','쿠션','리퀴드파운데이션','쿠션','스틱파운데이션','쿠션','스틱파운데이션','쿠션','스틱파운데이션','스틱파운데이션',
    '쿠션','쿠션','쿠션','쿠션','쿠션','쿠션','파운데이션','쿠션','쿠션','스틱파운데이션','쿠션','파운데이션','스틱파운데이션','스틱파운데이션']

# %%
cos_info.loc[5,'종류'] = '파운데이션'

# %%
cos_info.to_pickle('화장품정보all.plk')

# %% [markdown]
# ---

# %% [markdown]
# # 평점

# %%
driver = webdriver.Chrome(options=options) 
url = "https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000198001&dispCatNo=1000001000700080011&trackingCd=Cat1000001000700080011_Small&t_page=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EA%B4%80&t_click=%EC%BF%A0%EC%85%98/%ED%8C%8C%EC%9A%B4%EB%8D%B0%EC%9D%B4%EC%85%98_%EC%A0%84%EC%B2%B4_%EA%B7%B8%EB%9D%BC%ED%8E%9C,%EB%8B%A4%EC%8A%88,%EB%91%90%EC%9E%89%EC%99%93,%EB%B9%84%EB%A0%88%EB%94%94,%EC%98%A4%EB%B8%8C%EC%A0%9C_%EC%83%81%ED%92%88%EC%83%81%EC%84%B8&t_number=1&tab=review"
#크롬 드라이버에 url 주소 넣고 실행
driver.get(url)

# 페이지가 완전히 로딩되도록 3초동안 기다림
time.sleep(3)

# %%
rating_selector = "div > div.star-container > div > div.rating-score"
total_selector = "div > div.total-count"
#name_selector = "div.GoodsDetailInfo_title-area__unu7g > h3"

# %%
#time.sleep(5)
rating = driver.find_elements(By.CSS_SELECTOR, rating_selector)
total = driver.find_elements(By.CSS_SELECTOR, total_selector)
#name = driver.find_elements(By.CSS_SELECTOR, name_selector)

# %%
results = []
for r, t in zip(rating, total):
    rate = r.text
    total = total.text
    results.append({"평점":rate, "총리뷰수": total})

# %%
results
# Out:
# []

# %%
for i in name:
    print(i.text)
# Out:
# 오브제 내추럴 커버 파운데이션 기획세트(+클렌징폼 50ml)

# %% [markdown]
# ---

# %% [markdown]
# ### Shadow Dom 뚫기
#
# https://guiyomi.tistory.com/157
# 개발자 도구 -> 설정 -> Show user agent shadow dom 옵션을 체크

# %%
# 1. 가장 바깥쪽 Host 찾기
host1 = driver.find_element(By.CSS_SELECTOR, 'oy-review-review-in-product')
root1 = driver.execute_script('return arguments[0].shadowRoot', host1)
time.sleep(3)
els = root1.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['oy-review-product-review-provider', 'oy-review-review-list-provider', 'div', 'h2', 'oy-review-review-overview', 'div', 'oy-review-photo-review-widget', 'oy-review-shutter-post-wrapper-for-product-detail', 'oy-review-ai-summary', 'oy-review-review-list']

# %%
# 2. 그 다음 층위(review-provider) 뚫기
host2 = root1.find_element(By.CSS_SELECTOR, 'oy-review-product-review-provider')
root2 = driver.execute_script('return arguments[0].shadowRoot', host2)
time.sleep(3)
els = root2.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['slot']

# %% [markdown]
# slot이 뜨면 왜 안되냐?

# %%
host3 = root1.find_element(By.CSS_SELECTOR, 'oy-review-review-list-provider')
root3 = driver.execute_script('return arguments[0].shadowRoot', host3)
time.sleep(3)
els = root3.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['slot']

# %%
# 3. 그 다음 층위(overview) 뚫기
host4 = root1.find_element(By.CSS_SELECTOR, 'oy-review-review-overview')
root4 = driver.execute_script('return arguments[0].shadowRoot', host4)
time.sleep(1)
els = root4.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['oy-review-review-overview-mobile', 'slot']

# %%
host5 = root4.find_element(By.CSS_SELECTOR, 'oy-review-review-overview-mobile')
root5 = driver.execute_script('return arguments[0].shadowRoot', host5)
time.sleep(1)
els = root5.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])<
# Out:
# ['div', 'oy-review-star-rating', 'slot', 'oy-review-attribute-summary', 'div', 'oy-review-common-button', 'oy-review-chevron-icon']

# %%
# 4. 마지막 별점 레이아웃(star-rating) 뚫기
host6 = root5.find_element(By.CSS_SELECTOR, 'oy-review-star-rating')
root6 = driver.execute_script('return arguments[0].shadowRoot', host6)
time.sleep(1)
els = root6.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['div', 'div', 'div', 'div', 'oy-review-star-icon', 'div', 'oy-review-star-icon', 'div', 'oy-review-star-icon', 'div', 'oy-review-star-icon', 'div', 'oy-review-star-icon', 'div', 'div']

# %%
# 5. 드디어 최종 데이터 추출!
rating_score = root6.find_element(By.CSS_SELECTOR, '.rating-score').text
total_count = root6.find_element(By.CSS_SELECTOR, '.total-count').text

print(f"평점: {rating_score}, 리뷰수: {total_count}")
# Out:
# 평점: 4.8, 리뷰수: 총 6,920건

# %%
url_list = cos_info.loc[:,'링크']

# %%
url_list
# Out:
# 0     https://www.oliveyoung.co.kr/store/goods/getGo...
# 1     https://www.oliveyoung.co.kr/store/goods/getGo...
# 2     https://www.oliveyoung.co.kr/store/goods/getGo...
# 3     https://www.oliveyoung.co.kr/store/goods/getGo...
# 4     https://www.oliveyoung.co.kr/store/goods/getGo...
# 5     https://www.oliveyoung.co.kr/store/goods/getGo...
# 6     https://www.oliveyoung.co.kr/store/goods/getGo...
# 7     https://www.oliveyoung.co.kr/store/goods/getGo...
# 8     https://www.oliveyoung.co.kr/store/goods/getGo...
# 9     https://www.oliveyoung.co.kr/store/goods/getGo...
# 10    https://www.oliveyoung.co.kr/store/goods/getGo...
# 11    https://www.oliveyoung.co.kr/store/goods/getGo...
# 12    https://www.oliveyoung.co.kr/store/goods/getGo...
# 13    https://www.oliveyoung.co.kr/store/goods/getGo...
# 14    https://www.oliveyoung.co.kr/store/goods/getGo...
# Name: 링크, dtype: object

# %%
url_list2 = url_list + ['&tab=review']

# %%
rating_data = []
for i in range(len(url_list2)):
    url = url_list2[i]
    driver.get(url)
    time.sleep(4)

    try:
        host1 = driver.find_element(By.CSS_SELECTOR, 'oy-review-review-in-product')
        root1 = driver.execute_script('return arguments[0].shadowRoot', host1)
        time.sleep(3)

        host4 = root1.find_element(By.CSS_SELECTOR, 'oy-review-review-overview')
        root4 = driver.execute_script('return arguments[0].shadowRoot', host4)
        time.sleep(3)
        #mobile 확인하기 
        host5 = root4.find_element(By.CSS_SELECTOR, 'oy-review-review-overview-mobile')
        root5 = driver.execute_script('return arguments[0].shadowRoot', host5)
        time.sleep(3)

        host6 = root5.find_element(By.CSS_SELECTOR, 'oy-review-star-rating')
        root6 = driver.execute_script('return arguments[0].shadowRoot', host6)
        time.sleep(3)

        rating_score = root6.find_element(By.CSS_SELECTOR, '.rating-score').text
        total_count = root6.find_element(By.CSS_SELECTOR, '.total-count').text

        name_element = driver.find_elements(By.CSS_SELECTOR, "h3[class*='GoodsDetailInfo_title']")
        name_text = name_element[0].text if name_element else "이름 없음"

        rating_data.append({'이름' : name_text, '평균리뷰점수' : rating_score, '리뷰수': total_count})

        print(f"{i+1}번째 상품 완료: {name_text}")

    except Exception as e:
        print(f"{i+1}번째 상품에서 오류 발생: {e}")
        continue # 에러 난 상품은 건너뛰고 다음 상품 진행
# Out:
# 1번째 상품 완료: 오브제 내추럴 커버 파운데이션 기획세트(+클렌징폼 50ml)
# 2번째 상품 완료: 비레디 블루 파운데이션 35ml
# 3번째 상품 완료: [덱스 PICK]오브제 퍼펙트 옴므 쿠션 15g (SPF50+PA+++)
# 4번째 상품 완료: 비레디 블루 쿠션 4세대 15g(SPF 34 PA++)
# 5번째 상품 완료: 다슈 맨즈 멀티 커버 스틱 파운데이션 ( 단품/기획 )
# 6번째 상품 완료: [맨즈파데1등] 그라펜 팁 스케치 멀티 커버 파운데이션 20ml
# 7번째 상품 완료: [착붙쿠션] 그라펜 핸섬 커버쿠션 2종 택1
# 8번째 상품 완료: [덱스 PICK] 오브제 내추럴 커버 파운데이션 13g (SPF50+, PA++++)
# 9번째 상품 완료: 비레디 블루 쿠션 4세대 리필 15g
# 10번째 상품 완료: 다슈 맨즈 아쿠아 매트 비비 쿠션 15g
# 11번째 상품 완료: [피부착붙컬러] 그라펜 매치업 파운데이션 40ml 단품/기획
# 12번째 상품 완료: 다슈 맨즈 아쿠아 매트 비비 쿠션 (리필용)
# 13번째 상품 완료: 다슈 맨즈 아쿠아 매트 비비쿠션 (본품+리필)
# 14번째 상품 완료: 다슈 맨즈 멀티 커버 스틱 파운데이션 12g 뉴트럴베이지 기획(+미니 톤 컨트롤 로션)
# 15번째 상품 완료: 두잉왓 소프트 블러링 필터 쿠션 15g 단품/기획

# %%
rate_df = pd.DataFrame(rating_data)
rate_df
# Out:
#                                                   이름 평균리뷰점수       리뷰수
# 0                  오브제 내추럴 커버 파운데이션 기획세트(+클렌징폼 50ml)    4.8  총 6,847건
# 1                                  비레디 블루 파운데이션 35ml    4.8    총 876건
# 2           [덱스 PICK]오브제 퍼펙트 옴므 쿠션 15g (SPF50+PA+++)    4.8    총 968건
# 3                     비레디 블루 쿠션 4세대 15g(SPF 34 PA++)    4.8  총 3,318건
# 4                     다슈 맨즈 멀티 커버 스틱 파운데이션 ( 단품/기획 )    4.8    총 666건
# 5                [맨즈파데1등] 그라펜 팁 스케치 멀티 커버 파운데이션 20ml    4.9    총 575건
# 6                           [착붙쿠션] 그라펜 핸섬 커버쿠션 2종 택1    4.7    총 451건
# 7    [덱스 PICK] 오브제 내추럴 커버 파운데이션 13g (SPF50+, PA++++)    4.8  총 3,828건
# 8                               비레디 블루 쿠션 4세대 리필 15g    4.9  총 1,713건
# 9                             다슈 맨즈 아쿠아 매트 비비 쿠션 15g    4.6     총 61건
# 10                 [피부착붙컬러] 그라펜 매치업 파운데이션 40ml 단품/기획    4.8    총 230건
# 11                          다슈 맨즈 아쿠아 매트 비비 쿠션 (리필용)    4.9     총 23건
# ...

# %%
df = pd.read_csv('리뷰수.csv')
df.head()
# Out:
#                                          이름  평균리뷰점수       리뷰수
# 0         오브제 내추럴 커버 파운데이션 기획세트(+클렌징폼 50ml)     4.8  총 6,847건
# 1                         비레디 블루 파운데이션 35ml     4.8    총 876건
# 2  [덱스 PICK]오브제 퍼펙트 옴므 쿠션 15g (SPF50+PA+++)     4.8    총 968건
# 3            비레디 블루 쿠션 4세대 15g(SPF 34 PA++)     4.8  총 3,318건
# 4            다슈 맨즈 멀티 커버 스틱 파운데이션 ( 단품/기획 )     4.8    총 666건

# %% [markdown]
# ---
# # 텍스트 리뷰 데이터

# %%
df = pd.read_csv('화장품정보.csv')

# %%
host2 = root1.find_element(By.CSS_SELECTOR, 'oy-review-review-list')
root2 = driver.execute_script('return arguments[0].shadowRoot', host2)
time.sleep(3)
els = root2.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])
# Out:
# ['div', 'oy-review-review-filter', 'ul', 'li', 'oy-review-review-item', 'li', 'oy-review-review-item', 'li', 'oy-review-review-item', 'li', 'oy-review-review-item', 'li', 'oy-review-review-item']

# %%
host2.find_element(By.CSS_SELECTOR, 'oy-review-review-list')
# Out:
# ------------------------------------------------------------------------
#
# NoSuchElementException                 Traceback (most recent call last)
#
# Cell In[52], line 1
#
# ----> 1 host2.find_element(By.CSS_SELECTOR, 'oy-review-review-list')
#
#
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webelement.py:533, in WebElement.find_element(self, by, value)
#
#     511 """Find an element given a By strategy and locator.
#
#     512
#
#     513 Args:
#
#    (...)
#
#     530     element = driver.find_element(By.ID, "foo")
#
#     531 """
#
#     532 by, value = self._parent.locator_converter.convert(by, value)
#
# --> 533 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
#
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#
#     506     params = {}
#
#     507 params["id"] = self._id
#
# ...

# %%
host3 = root2.find_element_by_tag_name('oy-review-review-item')
root3 = driver.execute_script('return arguments[0].shadowRoot', host3)
time.sleep(3)

# %%
els = root3.find_elements(By.CSS_SELECTOR, '*')
print([e.tag_name for e in els])

# %%
items = root2.find_element(By.CSS_SELECTOR, 'div.review-item > div.inner')
# Out:
# --------------------------------------------------------------------------
#
# NoSuchElementException                   Traceback (most recent call last)
#
# Cell In[15], line 1
#
# ----> 1 items = root2.find_element(By.CSS_SELECTOR, 'div.review-item > div.inner')
#
#
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\shadowroot.py:81, in ShadowRoot.find_element(self, by, value)
#
#      78     by = By.CSS_SELECTOR
#
#      79     value = f'[name="{value}"]'
#
# ---> 81 return self._execute(Command.FIND_ELEMENT_FROM_SHADOW_ROOT, {"using": by, "value": value})["value"]
#
#
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\shadowroot.py:133, in ShadowRoot._execute(self, command, params)
#
#     131     params = {}
#
#     132 params["shadowId"] = self._id
#
# --> 133 return self.session.execute(command, params)
#
#
#
# ...

# %%
[i.text for i in host3]
# Out:
# ['까칠한40\nTOP 34\n복합성\n웜톤\n미백\n주름\n2025.12.07\n[옵션] 3호 기획(+클렌징폼 50ml)\n남성전용제품이라 파데색이 좋아요\n그리고 스틱형이라 간편하게 사용가능하답니다\n아침 출근 스킨 로션 바르기 번거로운데\n\n올인원파데 사주니 편하다고 해요\n요아이 스킨로션 포함한 올인원이거든요\n\n무엇보다 스틱형이라 사용이 간편하고\n반대쪽에는 촘촘한 브러쉬가 모공까지 싹다 매꿔줘요\n\n피지 많은 신랑인데 시간 지나도 무너지거나 하지 않고\n지속성 좋고 발림성이 좋아 왕모공도 싹다 커버해줘요\n색은 과하지 않은 자연스런 색상이구요\n\n클렌징도 잘되요\n함께 클렌징제품이 와서 신랑이 맘에 들어했어요\n신랑이나 아들 선물로 주기 괜찮아요\n색이 밝아서 뜨는 파데 아니라 자연스럽고 좋습니다\n신고하기\n5',
#  '올리브자몽\nTOP 17\n복합성\n여름쿨톤\n잡티\n주름\n2025.12.07\n[옵션] 3호 기획(+클렌징폼 50ml)\n남편이 중요한 출장을 앞두고 있어 쓰라고 사줬어요. \n가뜩이나 올영 세일해서 좋은데 50미리 클렌징폼도 주는 파운데이션 기획세트라 혜자롭네요. \n남편은 살짝 어두운 피부이기도 하고 출장지 미팅에서 진중하게 보여질 필요도 있어 3호로 골랐어요. \n배송받아 써보니 모공이 안보이게 커버가 잘 되고 피부톤도 고르게 자연스러워 보여서 좋네요. \n남편은 피부 결점커버가 잘 되어 좋기도 하지만 무엇보다 끈적이지 않고 땀에도 잘 지워지지 않는점이 마음에 든다고 해요.\n신고하기\n6',
# ...

# %%
name = driver.find_elements(By.CSS_SELECTOR, 'div.inner')
len(name)
# Out:
# 0

# %% [markdown]
# ---
# # 최후의 보루

# %%
from pyshadow.main import Shadow

# %%
options = Options()

options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/120.0.0.0 Safari/537.36"
)

driver = webdriver.Chrome(options=options) 
url = "https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000198001&dispCatNo=1000001000700080011&trackingCd=Cat1000001000700080011_Small&t_page=%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EA%B4%80&t_click=%EC%BF%A0%EC%85%98/%ED%8C%8C%EC%9A%B4%EB%8D%B0%EC%9D%B4%EC%85%98_%EC%A0%84%EC%B2%B4_%EA%B7%B8%EB%9D%BC%ED%8E%9C,%EB%8B%A4%EC%8A%88,%EB%91%90%EC%9E%89%EC%99%93,%EB%B9%84%EB%A0%88%EB%94%94,%EC%98%A4%EB%B8%8C%EC%A0%9C_%EC%83%81%ED%92%88%EC%83%81%EC%84%B8&t_number=1&tab=review"
#크롬 드라이버에 url 주소 넣고 실행
driver.get(url)

# 페이지가 완전히 로딩되도록 3초동안 기다림
time.sleep(3)

# %%
shadow = Shadow(driver)

# %%
rate = shadow.find_elements("div div.star-container div div.rating-score")
total = shadow.find_elements("div div.total-count")

# %%
shadow.find_element_by_xpath

# %%
rating_score = [r.text for r in rate]
total_count = [t.text for t in total]

# %%
print(f"평점: {rating_score}, 리뷰수: {total_count}")
# Out:
# 평점: ['4.8'], 리뷰수: ['총 6,932건']

# %%
[t.text for t in total]
# Out:
# ['총 6,932건']

# %% [markdown]
# #### 실행전에 스크롤 내리세요

# %%
driver.execute_script('window.scrollBy(0, 1500);')
time.sleep(3)

# %%
# 유저네임
name = shadow.find_elements('div.inner oy-review-review-user div.info div.name')

# %%
[n.text for n in name]
# Out:
# ['까칠한40', '올리브자몽', '민이몽', 'chocolatesh', 'hyunju184', '초코무스', '슈팅린다']

# %%
len(name)
# Out:
# 7

# %% [markdown]
# 피부톤은 설정하지 않은 사람들이 있어서 이거 처리

# %%
# 피부톤
skin_type = shadow.find_elements('div.inner oy-review-review-user div.info div.skin-types')

# %%
skin_list = []
if skin_type:
        # 정보가 있으면 텍스트 처리해서 추가
        skin_list.append(skin_type[0].text.replace('\n', ','))
else:
        # 정보가 없으면 None 혹은 "결측"을 추가 (이게 핵심입니다!)
        skin_list.append(None)

# %%
# 1. 유저 정보가 들어있는 '부모 컨테이너'를 먼저 찾습니다. (항상 4개가 잡힐 것입니다)
users = shadow.find_elements('div.inner oy-review-review-user div.info')

name_list = []
skin_list = []

for user in users:
    # 2. 부모 컨테이너 안에서 이름을 찾습니다.
    # .find_elements(부모 안에서 찾기)를 사용하면 에러 없이 개수 체크가 가능합니다.
    n_el = user.find_elements(By.CSS_SELECTOR, 'div.name')
    name_list.append(n_el[0].text if n_el else "이름없음")

    # 3. 부모 컨테이너 안에서 피부톤 정보를 찾습니다.
    s_el = user.find_elements(By.CSS_SELECTOR, 'div.skin-types')
    
    if s_el:
        # 정보가 있으면 텍스트 처리해서 추가
        skin_list.append(s_el[0].text.replace('\n', ','))
    else:
        # 정보가 없으면 None 혹은 "결측"을 추가 (이게 핵심입니다!)
        skin_list.append(None) 

# 결과 확인
print(len(name_list)) # 4
print(len(skin_list)) # 4 (데이터 개수가 맞춰짐!)
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[3], line 2
#
#       1 # 1. 유저 정보가 들어있는 '부모 컨테이너'를 먼저 찾습니다. (항상 4개가 잡힐 것입니다)
#
# ----> 2 users = shadow.find_elements('div.inner oy-review-review-user div.info')
#
#       4 name_list = []
#
#       5 skin_list = []
#
#
#
# NameError: name 'shadow' is not defined

# %%
skin_list
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 1
#
# ----> 1 skin_list
#
#
#
# NameError: name 'skin_list' is not defined

# %%
len(skin_type)
# Out:
# 6

# %%
[s.text.replace('\n',",") for s in skin_type]
# Out:
# ['복합성,웜톤,미백,주름',
#  '복합성,여름쿨톤,잡티,주름',
#  '복합성,겨울쿨톤,잡티,주름',
#  '지성,웜톤,트러블',
#  '복합성,웜톤,잡티,미백',
#  '복합성,쿨톤,잡티,탄력']

# %%
# 별점
star_rating = shadow.find_elements('div.inner div.rating > oy-review-star-icon')

# %% [markdown]
# # 별점 자동화
# reviews = shadow.find_elements(
#     "css selector",
#     "li oy-review-review-item"
# )
#
# for r in reviews:
#     stars = shadow.find_elements(
#         "css selector",
#         "div.inner div.rating oy-review-star-icon"
#     )
#     rating = len(stars)
#     print(rating)

# %%
# 리뷰날짜 
date = shadow.find_elements('div.inner div.common-info span.date')

# %%
len(date)
# Out:
# 9

# %%
[d.text for d in date]
# Out:
# ['2023.11.27',
#  '2025.10.17',
#  '2025.10.17',
#  '2025.10.16',
#  '2025.10.15',
#  '2025.10.10',
#  '2025.09.30',
#  '2025.09.18',
#  '2025.09.11']

# %%
# 리뷰내용 
text = shadow.find_elements('div.inner> oy-review-review-content > div > div.content')
#text = shadow.find_elements('div.content')

#text.text.replace('\n'," ")
[t.text.replace('\n'," ") for t in text]
#len(text)
# Out:
# ['두껍게 바르는 경우가 있는데 그럴땐 조금만 바르고 뒤에 있는 브러쉬로 쓱쓱 하는게 좋을 것 같아요. 브러쉬가 더러워 질 수 있는데 그건 어쩔수 없는 것 같아요. 사용하고 뒤에 달려있는 브러쉬 주변을 물티수로 닦아주는 것도 좋을 것 같아요. 엄청 극 지성만 아니라면 사용하기에 괜찮을 것 같아요.']

# %%
# 상품옵션
goods_option = shadow.find_elements('div.inner > div.goods-option')
[option.text for option in goods_option]
# Out:
# ['[옵션] 2호 베이지 13g']

# %%
len(goods_option)
# Out:
# 1

# %%
goods_option
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0a01a516c52a5f18a3db8f4e419cc59e", element="f.E91E45BB9365F044C14DBA93462FB627.d.A832ED6BB9A63FBD2FB2C59AE0D08095.e.1525373")>]

# %% [markdown]
# # 무한스크롤 끝 페이지까지 만들기

# %%
def infinite_loop():
    # 최초 페이지 스크롤 설정
    # 스크롤 시키지 않았을 때의 전체 높이
    last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        # 윈도우 창을 0에서 위에서 설정한 전체 높이로 이동
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(1.0)
        # 스크롤 다운한 만큼의 높이를 신규 높이로 설정 
        new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
        # 직전 페이지 높이와 신규 페이지 높이 비교
        if new_page_height == last_page_height:
            time.sleep(1.0)
            # 신규 페이지 높이가 이전과 동일하면, while문 break
            if new_page_height == driver.execute_script("return document.documentElement.scrollHeight"):
                break
        else:
            last_page_height = new_page_height

# %% [markdown]
# 1. 화장품 리뷰 페이지 들어가기
# 2. 무한스크롤로 페이지 로드
# 3. 요소를 뽑기
# 4. 해당 리뷰페이지 데이터 프레임 만들기
# 5. 다음 리뷰페이지 들어가기
# 6. concat 묶기

# %%
def review_text(url):
    driver = webdriver.Chrome(options=options) 
    url = url
    #크롬 드라이버에 url 주소 넣고 실행
    driver.get(url)

    # 페이지가 완전히 로딩되도록 3초동안 기다림
    time.sleep(3)
    shadow = Shadow(driver)

    # 유저네임
    name = shadow.find_elements('div.inner oy-review-review-user div.name')
    name_li = [n.text for n in name]

    #피부톤
    skin_type = shadow.find_elements('div.inner oy-review-review-user div.skin-types')
    

    #리뷰 날짜
    date = shadow.find_elements('div.inner div.common-info span.date')
    date_li = [d.text for d in date]

    #리뷰 내용
    text = shadow.find_elements('div.inner> oy-review-review-content > div > div.content')
    text_li = [t.text for t in text]

    # 상품옵션
    goods_option = shadow.find_elements('div.inner > div.goods-option')
    [o.text for o in goods_option]

# %%
infinite_loop()
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[55], line 1
#
# ----> 1 infinite_loop()
#
#
#
# Cell In[53], line 9, in infinite_loop()
#
#       6 while True:
#
#       7     # 윈도우 창을 0에서 위에서 설정한 전체 높이로 이동
#
#       8     driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
#
# ----> 9     time.sleep(1.0)
#
#      10     # 스크롤 다운한 만큼의 높이를 신규 높이로 설정
#
#      11     new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
#
#
#
# KeyboardInterrupt:
